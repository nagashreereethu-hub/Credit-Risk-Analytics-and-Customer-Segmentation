# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Nagashree M\\Desktop'

# %%
df=pd.read_csv(r"C:\Users\Nagashree M\Desktop\nagashree.py\credit risk.csv")

# %%
df.head()
# Out:
#      CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383.0  Existing Customer          45.0      M              3.0
# 1  818770008.0  Existing Customer          49.0      F              5.0
# 2  713982108.0  Existing Customer          51.0      M              3.0
# 3  769911858.0  Existing Customer          40.0      F              4.0
# 4  709106358.0  Existing Customer          40.0      M              3.0
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0            39.0  ...          11914.0                 1.335
# ...

# %%
df.shape
# Out:
# (11191, 25)

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Customer_status', 'Avg_Utilization_Ratio.1', 'Customer_Segment',
#        'Utilization_Level'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of          CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383.0  Existing Customer          45.0      M              3.0
# 1      818770008.0  Existing Customer          49.0      F              5.0
# 2      713982108.0  Existing Customer          51.0      M              3.0
# 3      769911858.0  Existing Customer          40.0      F              4.0
# 4      709106358.0  Existing Customer          40.0      M              3.0
# ...            ...                ...           ...    ...              ...
# 11186          NaN                NaN           NaN    NaN              NaN
# 11187          NaN                NaN           NaN    NaN              NaN
# 11188          NaN                NaN           NaN    NaN              NaN
# 11189          NaN                NaN           NaN    NaN              NaN
# 11190          NaN                NaN           NaN    NaN              NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                   1064
# Attrition_Flag              1064
# Customer_Age                1064
# Gender                      1064
# Dependent_count             1064
# Education_Level             1064
# Marital_Status              1064
# Income_Category             1064
# Card_Category               1064
# Months_on_book              1064
# Total_Relationship_Count    1064
# Months_Inactive_12_mon      1064
# Contacts_Count_12_mon       1064
# Credit_Limit                1064
# Total_Revolving_Bal         1064
# Avg_Open_To_Buy             1064
# Total_Amt_Chng_Q4_Q1        1064
# Total_Trans_Amt             1064
# Total_Trans_Ct              1064
# Total_Ct_Chng_Q4_Q1         1064
# Avg_Utilization_Ratio       1064
# Customer_status             1064
# Avg_Utilization_Ratio.1     1064
# Customer_Segment            1064
# Utilization_Level           1064
# dtype: int64

# %%
df.shape
# Out:
# (11191, 25)

# %%
df.tail()
# Out:
#        CLIENTNUM Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 11186        NaN            NaN           NaN    NaN              NaN
# 11187        NaN            NaN           NaN    NaN              NaN
# 11188        NaN            NaN           NaN    NaN              NaN
# 11189        NaN            NaN           NaN    NaN              NaN
# 11190        NaN            NaN           NaN    NaN              NaN
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 11186             NaN            NaN             NaN           NaN
# 11187             NaN            NaN             NaN           NaN
# 11188             NaN            NaN             NaN           NaN
# 11189             NaN            NaN             NaN           NaN
# 11190             NaN            NaN             NaN           NaN
#
#        Months_on_book  ...  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 11186             NaN  ...              NaN                   NaN
# ...

# %%
df = df.dropna(how='all')

# %%
df.shape
# Out:
# (10127, 25)

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# Customer_status             0
# Avg_Utilization_Ratio.1     0
# Customer_Segment            0
# Utilization_Level           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Customer_status', 'Avg_Utilization_Ratio.1', 'Customer_Segment',
#        'Utilization_Level'],
#       dtype='object')

# %%
df.rename(columns={'Avg_Utilization_Ratio.1':'Risk_Category'},inplace=True)
# Out:
# C:\Users\Nagashree M\AppData\Local\Temp\ipykernel_25156\273393642.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Avg_Utilization_Ratio.1':'Risk_Category'},inplace=True)

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Customer_status', 'Risk_Category', 'Customer_Segment',
#        'Utilization_Level'],
#       dtype='object')

# %%
df['Attrition_Flag'].value_counts()
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
(1627/10127)*100
# Out:
# 16.065962279055988

# %%
df['Attrition_Flag'].value_counts().plot(kind='bar')
plt.title("Customer Churn Analysis")
plt.show()

# %%
df['Risk_Category'].value_counts()
# Out:
# Risk_Category
# Low Risk       6253
# Medium Risk    2815
# High Risk      1059
# Name: count, dtype: int64

# %%
df['Risk_Category'].value_counts().plot(kind='bar')
plt.title("Risk Category Distribution")
plt.show()

# %%
df['Customer_Segment'].value_counts()
# Out:
# Customer_Segment
# Premium        7190
# High Income    1535
# Mid Income     1402
# Name: count, dtype: int64

# %%
df['Customer_Segment'].value_counts().plot(kind='bar')
plt.title("Customer Segment Distribution")
plt.show()

# %%
df.groupby('Customer_Segment')['Total_Trans_Amt'].sum()
# Out:
# Customer_Segment
# High Income     6881344.0
# Mid Income      6239899.0
# Premium        31478939.0
# Name: Total_Trans_Amt, dtype: float64

# %%
df.groupby('Risk_Category')['Total_Trans_Amt'].mean()
# Out:
# Risk_Category
# High Risk      3606.558074
# Low Risk       4614.726691
# Medium Risk    4236.217052
# Name: Total_Trans_Amt, dtype: float64

# %%
df.groupby('Risk_Category')['Total_Trans_Amt'].mean().plot(kind='bar')
plt.title('Average Spending by Risk Category')
plt.ylabel('Average Transaction Amount')
plt.show()

# %%
df.groupby('Risk_Category')['Credit_Limit'].mean()
# Out:
# Risk_Category
# High Risk       2504.770916
# Low Risk       12118.305405
# Medium Risk     3192.710124
# Name: Credit_Limit, dtype: float64

# %%
df.groupby('Risk_Category')['Credit_Limit'].mean().plot(kind='bar')
plt.title('Average Credit Limit by Risk Category')
plt.show()

# %%
df['Customer_Age'].hist(bins=10)
plt.title('Customer Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
df['Gender'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %%
df['Income_Category'].value_counts().plot(kind='bar')
plt.title('Income Category Distribution')
plt.show()

# %%
df.groupby('Risk_Category')['Total_Trans_Ct'].mean().plot(kind='bar')
plt.title('Average Transaction Count by Risk Category')
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.heatmap(
    df[['Credit_Limit',
        'Total_Revolving_Bal',
        'Total_Trans_Amt',
        'Total_Trans_Ct',
        'Avg_Utilization_Ratio']].corr(),
    annot=True
)
plt.title('Correlation Matrix')
plt.show()
